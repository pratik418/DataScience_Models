# %%
#Exercise 1: Prime Numbers
#Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

number = int(input("Enter a number: "))
if number > 1:
    for i in range(2, number):
        if number % i == 0:
            print(number, "is not a prime number.")
            break
    else:
        print(number, "is a prime number.")
else:
    print(number, "is not a prime number.")
# Out:
# Enter a number:  6
# 6 is not a prime number.

# %%
#Exercise 2: Product of Random Numbers
#Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

import random
number1 = random.randint(1, 100)
number2 = random.randint(1, 100)
print(f"First random integer: {number1}")
print(f"Second random integer: {number2}")
user_answer = int(input("Enter your answer: "))
correct_answer = number1 * number2
if user_answer == correct_answer:
    print("Your answer is correct!")
else:
    print(f"Your answer is incorrect. The correct answer is {correct_answer}.")
# Out:
# First random integer: 40
# Second random integer: 19
# Enter your answer:  76
# Your answer is incorrect. The correct answer is 760.

# %%
#Exercise 3: Squares of Even/Odd Numbers
#Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

user_choice = input("Enter 'even' to print even numbers or 'odd' to print odd numbers: ").strip().lower()

if user_choice == "even":
    print("Squares of EVEN numbers from 100 to 200:")
    for num in range(100, 201):
        if num % 2 == 0:
            print(f"Squares of EVEN number {num}^2  =", num ** 2)

elif user_choice == "odd":
    print("Squares of ODD numbers from 100 to 200:")
    for num in range(100, 201):
        if num % 2 != 0:
            print(f"Squares of ODD number {num}^2  =", num ** 2)

else:
    print("Invalid choice! Please enter 'even' or 'odd'.")
# Out:
# Enter 'even' to print even numbers or 'odd' to print odd numbers:  even
# Squares of EVEN numbers from 100 to 200:
# Squares of EVEN number 100^2  = 10000
# Squares of EVEN number 102^2  = 10404
# Squares of EVEN number 104^2  = 10816
# Squares of EVEN number 106^2  = 11236
# Squares of EVEN number 108^2  = 11664
# Squares of EVEN number 110^2  = 12100
# Squares of EVEN number 112^2  = 12544
# Squares of EVEN number 114^2  = 12996
# Squares of EVEN number 116^2  = 13456
# Squares of EVEN number 118^2  = 13924
# Squares of EVEN number 120^2  = 14400
# Squares of EVEN number 122^2  = 14884
# Squares of EVEN number 124^2  = 15376
# Squares of EVEN number 126^2  = 15876
# Squares of EVEN number 128^2  = 16384
# Squares of EVEN number 130^2  = 16900
# Squares of EVEN number 132^2  = 17424
# Squares of EVEN number 134^2  = 17956
# Squares of EVEN number 136^2  = 18496
# Squares of EVEN number 138^2  = 19044
# Squares of EVEN number 140^2  = 19600
# Squares of EVEN number 142^2  = 20164
# Squares of EVEN number 144^2  = 20736
# Squares of EVEN number 146^2  = 21316
# Squares of EVEN number 148^2  = 21904
# Squares of EVEN number 150^2  = 22500
# Squares of EVEN number 152^2  = 23104
# Squares of EVEN number 154^2  = 23716
# Squares of EVEN number 156^2  = 24336
# Squares of EVEN number 158^2  = 24964
# Squares of EVEN number 160^2  = 25600
# Squares of EVEN number 162^2  = 26244
# Squares of EVEN number 164^2  = 26896
# Squares of EVEN number 166^2  = 27556
# Squares of EVEN number 168^2  = 28224
# Squares of EVEN number 170^2  = 28900
# Squares of EVEN number 172^2  = 29584
# Squares of EVEN number 174^2  = 30276
# Squares of EVEN number 176^2  = 30976
# Squares of EVEN number 178^2  = 31684
# Squares of EVEN number 180^2  = 32400
# Squares of EVEN number 182^2  = 33124
# Squares of EVEN number 184^2  = 33856
# Squares of EVEN number 186^2  = 34596
# Squares of EVEN number 188^2  = 35344
# Squares of EVEN number 190^2  = 36100
# Squares of EVEN number 192^2  = 36864
# Squares of EVEN number 194^2  = 37636
# Squares of EVEN number 196^2  = 38416
# Squares of EVEN number 198^2  = 39204
# Squares of EVEN number 200^2  = 40000

# %%
#Exercise 4:
#✅ Problem Statement (Question): Hospital Billing System
#A hospital charges its patients based on the following:
#•	Room charges per day: ₹2,000
#•	Doctor consultation fee (flat): ₹1,500
#•	Lab test charges: Based on the number of tests taken. Each test costs ₹300
#•	Medicine charges: Total cost of medicines provided
#•	Discount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied
#Write a Python program to calculate the final bill for a patient who:
#•	Stayed for 4 days
#•	Had 3 lab tests
#•	Had medicine charges of ₹2,400

room_charge_per_day = 2000
doctor_fee = 1500
lab_test_cost = 300
discount_threshold = 10000
discount_rate = 0.1

# Patient bill calcuation details
days_stayed = 4
lab_test_number = 3
medicine_charges = 2400

# Calculation
room_charges = room_charge_per_day * days_stayed
lab_charges = lab_test_cost * lab_test_number
total_before_discount = room_charges + doctor_fee + lab_charges + medicine_charges

# Apply discount logic
if total_before_discount > discount_threshold:
    discount_amount = total_before_discount * discount_rate
else:
    discount_amount = 0

final_amount = total_before_discount - discount_amount

print("------ Hospital Bill ------")
print("Room Charges:", room_charges)
print("Doctor Consultation Fee:", doctor_fee)
print("Lab Test Charges:", lab_charges)
print("Medicine Charges:", medicine_charges)
print("Total Before Discount:", total_before_discount)
print("Discount Applied:", discount_amount)
print("Final Bill Amount:", final_amount)
# Out:
# ------ Hospital Bill ------
# Room Charges: 8000
# Doctor Consultation Fee: 1500
# Lab Test Charges: 900
# Medicine Charges: 2400
# Total Before Discount: 12800
# Discount Applied: 1280.0
# Final Bill Amount: 11520.0
